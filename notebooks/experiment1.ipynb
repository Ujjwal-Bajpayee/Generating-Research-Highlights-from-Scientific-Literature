# %%
import pandas as pd

# %%
train_data = pd.read_csv("../data/MixSub-SciHigh_train_FIRE.csv")

# %%
train_data.head()
# Out:
#    Filename                                           Abstract  \
# 0         1  Recent field data analyses have shown that lum...
# 1         2  Though U.S. motor vehicle crashes as a whole h...
# 2         3  Mindful organizing is a team level construct t...
# 3         4  Numerous studies have previously used a variet...
# 4         5  Advance guide signs for exit ramps along urban...
#
#                                           Highlights
# 0  Risk factors of lumbar spine fractures in fron...
# 1  Deaths from pedestrian crashes and drug overdo...
# 2  Development of a Spanish version of the Mindfu...
# 3  A tobit model coupled with correlated random p...
# 4  Better design alternatives of advance guide si...

# %%
count=train_data['Abstract'].count()
print(count)
# Out:
# 10000
